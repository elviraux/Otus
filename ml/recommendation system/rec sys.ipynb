# %% [markdown]
# # Recommendation system Amazon Music dataset
#
#
# author: Elvira Dzhuraeva

# %%
import pandas as pd
import numpy as np
from scipy import sparse
from lightfm import LightFM
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# /Users/edzhurae/anaconda3/lib/python3.7/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn('LightFM was compiled without OpenMP support. '

# %%
reviews = pd.read_json('Digital_Music_5.json', lines=True)
music =  pd.read_csv('amazon_music_metadata.csv')

# %%
interactions = reviews.groupby(['reviewerID', 'asin'])['overall'].sum().unstack().reset_index().fillna(0).set_index('reviewerID')
interactions.shape
# Out:
# (5541, 3568)

# %%
interactions.head()
# Out:
# asin                  5555991584  B0000000ZW  B00000016T  B00000016W  \
# reviewerID
# A08161909WK3HU7UYTMW         0.0         0.0         0.0         0.0
# A1020L7BWW9RAX               0.0         0.0         0.0         0.0
# A10323WWTFPSGP               0.0         0.0         0.0         0.0
# A103KNDW8GN92L               0.0         0.0         0.0         0.0
# A103W7ZPKGOCC9               0.0         0.0         0.0         0.0
#
# asin                  B00000017R  B0000001P4  B0000002HZ  B0000002J9  \
# reviewerID
# A08161909WK3HU7UYTMW         0.0         0.0         0.0         0.0
# A1020L7BWW9RAX               0.0         0.0         0.0         0.0
# A10323WWTFPSGP               0.0         0.0         0.0         0.0
# A103KNDW8GN92L               0.0         0.0         0.0         0.0
# A103W7ZPKGOCC9               0.0         0.0         0.0         0.0
#
# asin                  B0000002JR  B0000002ME  ...  B00II5VHBU  B00IOVH8AW  \
# reviewerID                                    ...
# A08161909WK3HU7UYTMW         0.0         0.0  ...         0.0         0.0
# A1020L7BWW9RAX               0.0         0.0  ...         0.0         0.0
# A10323WWTFPSGP               0.0         0.0  ...         0.0         0.0
# A103KNDW8GN92L               0.0         0.0  ...         0.0         0.0
# A103W7ZPKGOCC9               0.0         0.0  ...         0.0         0.0
#
# asin                  B00IXZ9QP4  B00J80ED9M  B00JJCQRDE  B00JJOG5D4  \
# reviewerID
# A08161909WK3HU7UYTMW         0.0         0.0         0.0         0.0
# A1020L7BWW9RAX               0.0         0.0         0.0         0.0
# A10323WWTFPSGP               0.0         0.0         0.0         0.0
# A103KNDW8GN92L               0.0         0.0         0.0         0.0
# A103W7ZPKGOCC9               0.0         0.0         0.0         0.0
#
# asin                  B00JRBLSR2  B00JTHVWO8  B00JYKU6BK  B00KILDVEI
# reviewerID
# A08161909WK3HU7UYTMW         0.0         0.0         0.0         0.0
# A1020L7BWW9RAX               0.0         0.0         0.0         0.0
# A10323WWTFPSGP               0.0         0.0         0.0         0.0
# A103KNDW8GN92L               0.0         0.0         0.0         0.0
# A103W7ZPKGOCC9               0.0         0.0         0.0         0.0
#
# [5 rows x 3568 columns]

# %%
def create_user_dict(interactions):
    user_id = list(interactions.index)
    user_dict = {}
    counter = 0 
    for i in user_id:
        user_dict[i] = counter
        counter += 1
    return user_dict

# %%
user_dict = create_user_dict(interactions=interactions)

# %%
def create_item_dict(df,id_col,name_col):
    item_dict ={}
    for i in range(df.shape[0]):
        item_dict[(df.loc[i,id_col])] = df.loc[i,name_col]
    return item_dict

# %%
music_dict = create_item_dict(df = music,
                               id_col = 'asin',
                               name_col = 'title')

# %%
x = sparse.csr_matrix(interactions.values)
model = LightFM(no_components= 30, loss='warp', k=15)
model.fit(x,epochs=30, num_threads = 4)

# %%
# mf_model = runMF(interactions = interactions,
#                  n_components = 30,
#                  loss = 'warp',
#                  k =15,
#                  epoch = 30,
#                  n_jobs = 4)

# %%
def sample_recommendation_user(model, interactions, user_id, user_dict, 
                               item_dict,threshold = 0,nrec_items = 10, show = True):
    n_users, n_items = interactions.shape
    user_x = user_dict[user_id]
    scores = pd.Series(model.predict(user_x,np.arange(n_items)))
    scores.index = interactions.columns
    scores = list(pd.Series(scores.sort_values(ascending=False).index))
    
    known_items = list(pd.Series(interactions.loc[user_id,:] \
                                 [interactions.loc[user_id,:] > threshold].index).sort_values(ascending=False))
    
    scores = [x for x in scores if x not in known_items]
    return_score_list = scores[0:nrec_items]
    known_items = list(pd.Series(known_items).apply(lambda x: item_dict[x]))
    scores = list(pd.Series(return_score_list).apply(lambda x: item_dict[x]))
    if show == True:
        print("Known Likes:")
        counter = 1
        for i in known_items:
            print(str(counter) + '- ' + i)
            counter+=1

        print("\n Recommended Items:")
        counter = 1
        for i in scores:
            print(str(counter) + '- ' + i)
            counter+=1
    return return_score_list

# %%
rec_list = sample_recommendation_user(model = model, 
                                      interactions = interactions, 
                                      user_id = 'A103KNDW8GN92L', 
                                      user_dict = user_dict,
                                      item_dict = music_dict, 
                                      threshold = 4,
                                      nrec_items = 10)
# Out:
# Known Likes:
# 1- Pretzel Logic
# 2- Royal Scam
# 3- Cant Buy a Thrill
# 4- Havana Daydreamin
# 5- Son of a Son of a Sailor
# 6- Tap Root Manuscript
# 7- Changes in Latitudes Changes in Attitudes
# 8- Living &amp; Dying in 3/4 Time
# 9- Stones
# 10- The Best Of 3 Dog Night
# 11- Second Helping
# 12- A1a
# 13- But Seriously
# 14- Abandoned Luncheonette
# 15- Face Value
# 16- Days of Future Passed
# 17- Beautiful Noise
# 18- Silk Degrees
# 19- Blood on the Tracks
# 20- Madman Across the Water
# 21- Captain Fantastic and the Brown Dirt Cowboy
# 22- Dont Shoot Me Im Only the Piano Player
# 23- Unorthodox Behavior
#
#  Recommended Items:
# 1- Elton John
# 2- Honky Ch&acirc;teau
# 3- Rock of the Westies
# 4- Caribou
# 5- Aja
# 6- 52nd Street
# 7- 21 At 33
# 8- Empty Sky
# 9- Long Distance Voyager
# 10- Seventh Sojourn

# %%
def sample_recommendation_item(model,interactions,item_id,user_dict,item_dict,number_of_user):
    n_users, n_items = interactions.shape
    x = np.array(interactions.columns)
    scores = pd.Series(model.predict(np.arange(n_users), np.repeat(x.searchsorted(item_id),n_users)))
    user_list = list(interactions.index[scores.sort_values(ascending=False).head(number_of_user).index])
    return user_list

# %%
recommend_users_ids = sample_recommendation_item(model = model,
                           interactions = interactions,
                           item_id = 'B00000016W',
                           user_dict = user_dict,
                           item_dict = music_dict,
                           number_of_user = 15)

# %%
reviews[reviews['reviewerID'].isin(recommend_users_ids)]
# Out:
#              asin   helpful  overall  \
# 60     B00000016T    [0, 0]        5
# 162    B00000016W    [3, 4]        5
# 178    B00000016W    [1, 2]        5
# 838    B00000064E    [4, 4]        5
# 876    B00000064F    [0, 1]        4
# 878    B00000064F   [2, 27]        3
# 941    B00000064G  [11, 13]        5
# 1137   B000000EDW    [1, 4]        1
# 1303   B000000IS5   [9, 15]        5
# 1326   B000000ISE    [1, 2]        4
# 1429   B000000OPC    [3, 6]        4
# 2055   B000000WGN    [2, 2]        5
# 2305   B000000YIQ    [4, 4]        5
# 2948   B000001A5X    [0, 0]        5
# 3028   B000001A6N    [0, 0]        5
# 3829   B000001DZO    [9, 9]        4
# 3915   B000001E0O    [1, 2]        2
# 4204   B000001EG6    [3, 3]        5
# 4373   B000001EGC    [1, 4]        4
# 4391   B000001EGE    [0, 0]        5
# 5191   B000001FAO    [5, 5]        5
# 5199   B000001FAO    [2, 2]        5
# 5210   B000001FAO    [1, 1]        5
# 5215   B000001FAO    [2, 2]        4
# 5387   B000001FFJ    [3, 5]        5
# 5650   B000001FWQ  [20, 22]        5
# 5681   B000001FXV    [4, 7]        5
# 6767   B0000024TT  [15, 18]        4
# 6806   B0000024UX  [19, 20]        5
# 7190   B00000253N   [6, 10]        5
# ...           ...       ...      ...
# 27323  B00000DQSF    [7, 7]        5
# 27335  B00000DQSF    [0, 0]        5
# 28669  B00000IPAC    [2, 2]        5
# 29076  B00000JC6C    [5, 7]        5
# 29692  B00001OH7M    [3, 3]        5
# 29804  B00001QGQI    [0, 2]        4
# 30362  B000028U0Y    [4, 6]        4
# 30687  B00003002C    [1, 1]        5
# 30717  B00003002C    [1, 1]        5
# 30753  B00003002C    [1, 1]        5
# 30755  B00003002C    [1, 1]        5
# 32292  B00004SYOP    [8, 8]        4
# 33577  B00004Y6NM   [3, 15]        1
# 33730  B00004YNGK    [0, 0]        5
# 34458  B000059L9A    [0, 1]        4
# 34968  B00005B4GB    [2, 2]        5
# 35745  B00005MLVA  [14, 14]        5
# 36158  B00005NUXS  [14, 16]        4
# 36883  B00005QK3W    [0, 0]        5
# 38978  B000069HKH    [0, 0]        4
# 39010  B000069HKH    [4, 5]        5
# 39031  B000069HKH  [19, 25]        5
# 39086  B00006BTC6    [2, 3]        4
# 39818  B00006L7XQ    [1, 1]        5
# 39848  B00006L7XQ    [3, 3]        4
# 42013  B00008V630    [4, 5]        4
# 54200  B000NJLQUQ    [0, 0]        5
# 56616  B001BM67QW    [1, 1]        5
# 56997  B001G93Z5Q    [0, 0]        3
# 58465  B002HQWQB6    [0, 0]        3
#
#                                               reviewText   reviewTime  \
# 60     These remarks are aboutASIN B0000262U4'The Car...   03 4, 2014
# 162    ...If fans stopped trying to play "Can You Top...  04 12, 2006
# 178    As a landlocked kid growing up without ready a...  10 10, 2008
# 838    Each album made by this cult hero from the 70'...  10 29, 2001
# 876    After the rainy mournfulness of his debut, Fiv...  10 31, 2001
# 878    This is so totaly relaxing that it takes actua...  06 25, 2003
# 941    In 1972, Nick Drake, just twenty-four years ol...  10 29, 2001
# 1137   This is my 2nd time out for Baez's second albu...  11 16, 2012
# 1303   As all concur this is a great jazz CD..know th...  10 30, 2005
# 1326   This cd is a combination of the U.K. release (...  08 13, 2001
# 1429   Although several songs here haven't aged well,...  04 25, 2002
# 2055   On this album, Roy sounds substantially as he ...  04 17, 2014
# 2305   The freshness of this enchanting CD cut in a f...   09 5, 2005
# 2948   Popular music had long been a hotbed for perso...  11 26, 2001
# 3028   This is arguably Stevie Wonder's finest album,...  03 21, 2012
# 3829   The expression that we use here in Chile when ...  12 14, 2000
# 3915   I have always enjoyed the Moody Blues having s...   02 9, 2001
# 4204   This was an excellent album when first release...   03 7, 2002
# 4373   An anything goes attitude is the defining feat...  05 17, 2003
# 4391   This period of time in EJ's career was my pers...  04 29, 2014
# 5191   There is a better sound to my ears on the delu...   04 1, 2005
# 5199   The album cover, one of the best examples of m...   06 1, 2006
# 5210   My remarks are aboutASIN B0000067L2 (April 7, ...   02 4, 2014
# 5215   What separates a power trio (such as ZZ Top or...  01 15, 2002
# 5387   Rain Dogs epitomizes, think-throated, eccentri...  10 26, 2002
# 5650   Whenever I pass by the Apollo,my mind goes bac...  12 26, 2006
# 5681   Live albums are rarely the top choices in a le...   11 4, 2001
# 6767   Leonard Cohen had always been nervous about en...   12 6, 2001
# 6806   The fact that over half of the songs on Bridge...  12 23, 2002
# 7190   BLOOD ON THE TRACKS is, arguably, Dylan's fine...  05 20, 2005
# ...                                                  ...          ...
# 27323  Eric Clapton in the liner notes of Blind Faith...  02 28, 2007
# 27335  There's been a lot written about "Big Pink" ov...   02 4, 2014
# 28669  More edgier and varied than 'Aja', which is ve...  01 15, 2003
# 29076  The Flaming Lips have been a band well worth n...   05 3, 2003
# 29692  The zoned-out photo of David Bowie on the cove...   04 4, 2002
# 29804  I stopped taking Sting seriously about 10 year...  10 28, 2001
# 30362  The clich&eacute; about Johnny Cash at Folsom ...   07 1, 2003
# 30687  This entire CD is Steely Dan at their best.  I...  04 27, 2014
# 30717  Great Album. Another old classic that was a mu...  02 26, 2014
# 30753  Slick it may be, but boy! can these cats play!...  12 15, 2000
# 30755  This is one of Donald Fagan & Walter Becker's ...  01 24, 2004
# 32292  This is a great cd by a great artist. It only ...   07 8, 2002
# 33577  horrible 80's production, voice not recovered ...  06 14, 2003
# 33730  Had this one recommended years ago by a friend...  02 26, 2014
# 34458  This is a very good album.  I bought it when i...  04 27, 2013
# 34968  Actually, since Rock Of Ages was a New Years e...   01 1, 2006
# 35745  Never mind if you have their previous greatest...   03 6, 2002
# 36158  In October 2001, his adoring legion of fans fi...  12 20, 2001
# 36883  If you loved his early albums then you will fa...  11 20, 2001
# 38978  Despite all the negative, disappointed reviews...   08 3, 2002
# 39010  The Rising, the triumphant return of Bruce Spr...   05 3, 2003
# 39031  This isn't Springsteen's best album musically ...   08 1, 2002
# 39086  This cd sounds incredible - Neko's voice is ha...  11 12, 2002
# 39818  A cryptic hypnotic album full of ruminations o...  12 22, 2007
# 39848  Few albums in recent memory - heck, few albums...   07 1, 2003
# 42013  The EP accompanying Fight Test, the third sing...   05 3, 2003
# 54200  Just got this cd and it's taken up residence i...   08 6, 2007
# 56616  Every year, it seems the critical press anoint...  06 18, 2009
# 56997  This third album from Razorlight shows a fair ...  06 18, 2009
# 58465  I had never heard Jupiter One before (heard 'o...  10 21, 2009
#
#            reviewerID                              reviewerName  \
# 60     A31I5XTQ5BAR9F                             Paul H Turley
# 162     AGKPTMTR3UX1R  Konrei "Everything I need is right here"
# 178    A2SYP47BL4TP9Q                                   Mike B.
# 838    A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 876    A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 878    A23YXA0AX47YPD                            R. Bruynesteyn
# 941    A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 1137   A291X75UCH6KN8                       Robert G. Daugherty
# 1303    AARJLW29JSF31                                   JG "jg"
# 1326   A280XKGM4KT0KN                                      doug
# 1429   A2XXT5BEO2RJ3P                             Greg McDowell
# 2055    ACU22OOTCPJDF                 Amazon Customer "tigerUK"
# 2305    AARJLW29JSF31                                   JG "jg"
# 2948   A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 3028    AGKPTMTR3UX1R  Konrei "Everything I need is right here"
# 3829   A2V5PFZFJ77BRA              Cristian Domarchi "Cristian"
# 3915   A280XKGM4KT0KN                                      doug
# 4204   A280XKGM4KT0KN                                      doug
# 4373   A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 4391    ACU22OOTCPJDF                 Amazon Customer "tigerUK"
# 5191    AARJLW29JSF31                                   JG "jg"
# 5199    AGKPTMTR3UX1R  Konrei "Everything I need is right here"
# 5210   A31I5XTQ5BAR9F                             Paul H Turley
# 5215   A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 5387   A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 5650    AARJLW29JSF31                                   JG "jg"
# 5681   A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 6767   A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 6806   A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 7190    AGKPTMTR3UX1R  Konrei "Everything I need is right here"
# ...               ...                                       ...
# 27323   AARJLW29JSF31                                   JG "jg"
# 27335  A31I5XTQ5BAR9F                             Paul H Turley
# 28669  A3MR1REKDWAQSV                        Richard Cunningham
# 29076  A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 29692  A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 29804  A2XXT5BEO2RJ3P                             Greg McDowell
# 30362  A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 30687   ACU22OOTCPJDF                 Amazon Customer "tigerUK"
# 30717   AB5LHD39AGWIM                                  G. Shirk
# 30753  A23YXA0AX47YPD                            R. Bruynesteyn
# 30755  A3MR1REKDWAQSV                        Richard Cunningham
# 32292  A1ILBKPRXHOO8P                               umze "umze"
# 33577  A23YXA0AX47YPD                            R. Bruynesteyn
# 33730   AB5LHD39AGWIM                                  G. Shirk
# 34458  A291X75UCH6KN8                       Robert G. Daugherty
# 34968   AARJLW29JSF31                                   JG "jg"
# 35745  A280XKGM4KT0KN                                      doug
# 36158  A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 36883  A280XKGM4KT0KN                                      doug
# 38978  A2XXT5BEO2RJ3P                             Greg McDowell
# 39010  A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 39031  A1ILBKPRXHOO8P                               umze "umze"
# 39086  A1ILBKPRXHOO8P                               umze "umze"
# 39818   AARJLW29JSF31                                   JG "jg"
# 39848  A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 42013  A3075RVSKC27HU          P. Nicholas Keppler "rorscach12"
# 54200  A3RICVFW2YD1LZ                  T. Scarillo "music snob"
# 56616  A3RICVFW2YD1LZ                  T. Scarillo "music snob"
# 56997  A3RICVFW2YD1LZ                  T. Scarillo "music snob"
# 58465  A3RICVFW2YD1LZ                  T. Scarillo "music snob"
#
#                                                  summary  unixReviewTime
# 60                   Great New Wave album, sounding good      1393891200
# 162                            "Wouldn't It Be Nice...?"      1144800000
# 178                              Here Comes The Sun King      1223596800
# 838                                    Might be his best      1004313600
# 876         A lighter, jazzier treatment of Nick's songs      1004486400
# 878                                       UNOBNOXIOUS...      1056499200
# 941                          Emotional, bare boned music      1004313600
# 1137                      I'd forgotten how bad this was      1353024000
# 1303    2 Versions Out There With Different Bonus Tracks      1130630400
# 1326                                    Trippy n' groovy       997660800
# 1429             A  Snapshot of The Reagen  Wasteland...      1019692800
# 2055                           The Return of Roy Orbison      1397692800
# 2305   New Mexico Space Within  A California Studio 1...      1125878400
# 2948    The beautiful album that changed R&amp;B forever      1006732800
# 3028               Innervisions can conquer any darkness      1332288000
# 3829                             Thank you for the music       976752000
# 3915                                        disappointed       981676800
# 4204                         #2 on my desert island five      1015459200
# 4373                 John and Tauplin at their strangest      1053129600
# 4391                                    One of EJ's best      1398729600
# 5191                       Maybe Their Cream Of The Crop      1112313600
# 5199   "Tiny purple fishes run laughing through your ...      1149120000
# 5210   Classic psychedelia, from when Clapton was God...      1391472000
# 5215   &quot;Carving deep blue ripples in the tissues...      1011052800
# 5387                                          Incredible      1035590400
# 5650   Intensity Of Soul...One Of The Greatest Live A...      1167091200
# 5681      One of the best live albums and Wailers albums      1004832000
# 6767             Leonard Cohen enters the world of music      1007596800
# 6806                                        Outstanding!      1040601600
# 7190            Early One Mornin' The Sun Was Shining...      1116547200
# ...                                                  ...             ...
# 27323               The Album That Changed Music Forever      1172620800
# 27335  The Band's seminal 'roots rock' album, beautif...      1391472000
# 28669                               Steely Dan's Finest!      1042588800
# 29076                               Flat-out masterpiece      1051920000
# 29692  &quot;I'm the cream of the great utopia dream....      1017878400
# 29804     A Strong Return To Form...About Half The Time.      1004227200
# 30362                                  Cash plays Folsom      1057017600
# 30687                                   70's masterpiece      1398556800
# 30717                                Another old Classic      1393372800
# 30753            In a perfect world everybody owns it...       976838400
# 30755                                                Aja      1074902400
# 32292                                    Second tier Eva      1026086400
# 33577                                 behind his peak...      1055548800
# 33730                                        Great Album      1393372800
# 34458          The Harsh Reviews are utterly unjustified      1367020800
# 34968  Happy New Year.....Music Like This Makes Any D...      1136073600
# 35745        Rhino Records you just keep getting better!      1015372800
# 36158    &quot;Oh, Crown of Light, Oh Darkened One&quot;      1008806400
# 36883                                       Bravo Paul!!      1006214400
# 38978            Heading Out Of Town To Win (Hopefully!)      1028332800
# 39010                       Springsteen reflects on 9/11      1051920000
# 39031                        The New Springsteen Classic      1028160000
# 39086                         Beautiful, beautiful noise      1037059200
# 39818            When death..the real Man Comes Around..      1198281600
# 39848                           Extraordinary experience      1057017600
# 42013                              A treat for Lips fans      1051920000
# 54200        THEIR BEST ALBUM IN YEARS - very satisfying      1186358400
# 56616  Excellent Debut - one I play front-to-back a l...      1245283200
# 56997   Shows some musical development since their debut      1245283200
# 58465            pleasant; album is slowly growing on me      1256083200
#
# [126 rows x 9 columns]

# %%
def create_item_emdedding_distance_matrix(model,interactions):
    df_item_norm_sparse = sparse.csr_matrix(model.item_embeddings)
    similarities = cosine_similarity(df_item_norm_sparse)
    item_emdedding_distance_matrix = pd.DataFrame(similarities)
    item_emdedding_distance_matrix.columns = interactions.columns
    item_emdedding_distance_matrix.index = interactions.columns
    return item_emdedding_distance_matrix

# %%
item_item_dist = create_item_emdedding_distance_matrix(model = model,
                                                       interactions = interactions)

# %%
def item_item_recommendation(item_emdedding_distance_matrix, item_id, 
                             item_dict, n_items = 10, show = True):
    recommended_items = list(pd.Series(item_emdedding_distance_matrix.loc[item_id,:]. \
                                  sort_values(ascending = False).head(n_items+1). \
                                  index[1:n_items+1]))
    if show == True:
        print("Item of interest: {0}".format(item_dict[item_id]))
        print("Item similar to the above item:")
        counter = 1
        for i in recommended_items:
            print(str(counter) + '- ' +  item_dict[i])
            counter+=1
    return recommended_items

# %%
rec_list = item_item_recommendation(item_emdedding_distance_matrix = item_item_dist,
                                    item_id = 'B0000002ME',
                                    item_dict = music_dict,
                                    n_items = 10)
# Out:
# Item of interest: Now That Ive Found You
# Item similar to the above item:
# 1- 9 to 5 &amp; Odd Jobs
# 2- Forget About It
# 3- No Place That Far
# 4- Pieces of the Sky
# 5- So Long So Wrong
# 6- Everybodys Got a Story
# 7- Yes I Am
# 8- Ive Got That Old Feeling
# 9- Five Days in July
# 10- Two Highways
